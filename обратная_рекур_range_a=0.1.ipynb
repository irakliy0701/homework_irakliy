# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
N = 100
a = np.zeros(N)

# %%
for i in range(2,N):
    a[N-i] = (1 - a[N-i+1]*(N-i+1))/((0.1)*(N+i-1))

# %%
plt.plot(a[1:])

# %%
a[25]
# Out:
# -8.003897440580916e+44

# %%
a
# Out:
# array([ 0.00000000e+00, -4.02571967e+39,  3.98546247e+40, -2.61712036e+41,
#         1.28238897e+42, -5.00131700e+42,  1.61709250e+43, -4.45855503e+43,
#         1.07005321e+44, -2.27089069e+44,  4.31469232e+44, -7.41342589e+44,
#         1.16143672e+45, -1.67068206e+45,  2.21962045e+45, -2.73753188e+45,
#         3.14816167e+45, -3.38890344e+45,  3.42655792e+45, -3.26424728e+45,
#         2.93782256e+45, -2.50414399e+45,  2.02608014e+45, -1.55920080e+45,
#         1.14341392e+45, -8.00389744e+44,  5.35645444e+44, -3.43209859e+44,
#         2.10828913e+44, -1.24316359e+44,  7.04459368e+43, -3.84043978e+43,
#         2.01623089e+43, -1.02033502e+43,  4.98163571e+42, -2.34848540e+42,
#         1.06986557e+42, -4.71319158e+41,  2.00930799e+41, -8.29483554e+40,
#         3.31793422e+40, -1.28671107e+40,  4.84048452e+39, -1.76733970e+39,
#         6.26602256e+38, -2.15829666e+38,  7.22560186e+37, -2.35216401e+37,
# ...
